# %%
from sklearn.cluster import KMeans
import numpy as np
import matplotlib.pyplot as plt

# %%
np.random.seed(42)

# %%
d1=np.random.normal(loc=[2,4],scale=1,size=(100,2))
d2=np.random.normal(loc=[4,8],scale=1,size=(100,2))
d3=np.random.normal(loc=[8,16],scale=1,size=(100,2))
data=np.vstack((d1,d2,d3))

# %%
plt.scatter(data[:,0],data[:,1],s=25,color="red",label="actual")
plt.legend()

# %%
model
model.fit(data)
KMeans(n_clusters=3,random_state=42)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 model.fit(data)
#       2 KMeans(n_clusters=3,random_state=42)
#
# NameError: name 'model' is not defined
