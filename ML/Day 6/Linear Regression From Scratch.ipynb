# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression 
from sklearn.model_selection import train_test_split
from sklearn import metrics

# %%
datasets=pd.read_excel("Advertising_Data.xlsx")
datasets.head()
# Out:
#     TV  Radio  Newspaper  Sales
# 0  230     37         69   22.1
# 1   44     39         45   10.4
# 2   17     45         69    9.3
# 3  151     41         58   18.5
# 4  180     10         33   12.9

# %%
x=datasets[["TV","Radio","Newspaper"]]

# %%
y=datasets[["Sales"]]

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=42)

# %%
model=LinearRegression()
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
print(model.intercept_)
# Out:
# [1.14144082]

# %%
print(model.coef_)
# Out:
# [[ 0.06784992  0.29264401 -0.08241923]]

# %%
y_pred=model.predict(x_test)
y_pred
# Out:
# array([[21.65719636],
#        [11.83108826],
#        [ 9.54971009]])

# %%
mean_absolute_error=metrics.mean_absolute_error(y_test,y_pred)
mean_absolute_error
# Out:
# 1.7126649018969156

# %%
mean_sq_error=metrics.mean_squared_error(y_test,y_pred)
mean_sq_error
# Out:
# 3.1370443522775653

# %%
root_m_sq_error=np.sqrt(metrics.mean_squared_error(y_test,y_pred))
root_m_sq_error
# Out:
# np.float64(1.7711703340665925)

# %%
x_single = datasets[["TV"]]
y_single = datasets["Sales"]

plt.figure(figsize=(6,5))
plt.scatter(x_test, y_test, color="red", label="Actual")
plt.plot(x_test, y_pred, color="blue", label="Predicted")
plt.xlabel("TV Advertising")
plt.ylabel("Sales")
plt.title("TV vs Sales (Linear Regression)")
plt.legend()
plt.show()
